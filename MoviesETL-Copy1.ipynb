# %%
import json
import pandas as pd
import numpy as np

# %%
file_dir = (r'C:\Users\David\Desktop\Class\Analysis_Projects\08-Wikipedia-Movies\Movies-ETL')

file_dir
# Out:
# 'C:\\Users\\David\\Desktop\\Class\\Analysis_Projects\\08-Wikipedia-Movies\\Movies-ETL'

# %%
with open(f'{file_dir}\wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
# len(wiki_movies_raw)

# %%
# First 5 records
#wiki_movies_raw[:5]

# %%
# Last 5 records
#wiki_movies_raw[-5:]

# %%
# Some records in the middle
#wiki_movies_raw[3600:3605]

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}\\movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}\\ratings.csv')

# %%
#kaggle_metadata.head(10)

# %%
#ratings.head(10)

# %%
#ratings.sample(n=10)

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
#wiki_movies_df.head()

# %%
#wiki_movies_df.columns.tolist()

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]
#len(wiki_movies)

# %%
wiki_movies_df2 = pd.DataFrame(wiki_movies)

# %%
#wiki_movies_df2.head()

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]

# %%
#x = 'global value'

#def foo():
#     x = 'local value'
#     print(x)

#foo()
#print(x)

# %%
#my_list = [1,2,3]
#def append_four(x):
#    x.append(4)
#append_four(my_list)
#print(my_list)

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune-Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'McCune–Reischauer',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'McCune–Reischauer',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#    Cinematography                                       Release date  \
# 0     Oliver Wood                  [July 11, 1990, (, 1990-07-11, )]
# 1    Mark Plummer  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2   Roger Deakins                [August 10, 1990, (, 1990-08-10, )]
# 3  Carlo Di Palma              [December 25, 1990, (, 1990-12-25, )]
# 4    Russell Boyd                                  December 19, 1990
#
#   Running time  ... Preceded by Suggested by alt_titles Recorded Venue Label  \
# 0  102 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 1  114 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 2  113 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 3  106 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 4   95 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
#
#   Animation by Color process McCune–Reischauer    imdb_id
# 0          NaN           NaN               NaN  tt0098987
# 1          NaN           NaN               NaN  tt0098994
# 2          NaN           NaN               NaN  tt0099005
# 3          NaN           NaN               NaN  tt0099012
# 4          NaN           NaN               NaN  tt0099018
#
# [5 rows x 41 columns]

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %%
wiki_movies_df.sample(5)
# Out:
#                                                     url  year  \
# 364           https://en.wikipedia.org/wiki/Life_Stinks  1991
# 2643  https://en.wikipedia.org/wiki/Gossip_(2000_Ame...  2000
# 2885  https://en.wikipedia.org/wiki/Josie_and_the_Pu...  2001
# 1842   https://en.wikipedia.org/wiki/Cats_Don%27t_Dance  1997
# 186   https://en.wikipedia.org/wiki/Pump_Up_the_Volu...  1990
#
#                                   imdb_link                    title  \
# 364   https://www.imdb.com/title/tt0102303/              Life Stinks
# 2643  https://www.imdb.com/title/tt0176783/                   Gossip
# 2885  https://www.imdb.com/title/tt0236348/  Josie and the Pussycats
# 1842  https://www.imdb.com/title/tt0118829/         Cats Don't Dance
# 186   https://www.imdb.com/title/tt0100436/       Pump Up the Volume
#
#                                         Based on  \
# 364                                          NaN
# 2643                                         NaN
# 2885  [Josie and the Pussycats, by, Dan DeCarlo]
# 1842                                         NaN
# 186                                          NaN
#
#                                                Starring      Cinematography  \
# 364   [Mel Brooks, Lesley Ann Warren, Jeffrey Tambor...       Steven Poster
# 2643  [James Marsden, Lena Headey, Norman Reedus, Ka...  Andrzej Bartkowiak
# 2885  [Rachael Leigh Cook, Tara Reid, Rosario Dawson...   Matthew Libatique
# 1842                        [Scott Bakula, Jasmine Guy]                 NaN
# 186   [Christian Slater, Scott Paulin, Ellen Greene,...          Walt Lloyd
#
#                                            Release date Running time  \
# 364                   [July 26, 1991, (, 1991-07-26, )]   92 minutes
# 2643                 [April 21, 2000, (, 2000-04-21, )]   90 minutes
# 2885  [April 11, 2001, (, 2001-04-11, ), (United Sta...   98 minutes
# 1842                 [March 28, 1997, (, 1997-03-28, )]   75 minutes
# 186                                     August 22, 1990  105 minutes
#
#                       Country  ...       Budget  \
# 364             United States  ...  $13 million
# 2643            United States  ...  $24 million
# 2885  [United States, Canada]  ...  $39 million
# 1842            United States  ...  $32 million
# 186     United States, Canada  ...          NaN
#
#                          Box office                        Director  \
# 364                    $4.1 million                      Mel Brooks
# 2643                    $12 million                Davis Guggenheim
# 2885                  $14.9 million  [Harry Elfont, Deborah Kaplan]
# 1842                   $3.6 million                     Mark Dindal
# 186   $11.5 million (United States)                     Allan Moyle
#
#                                             Distributor  \
# 364                                 Metro-Goldwyn-Mayer
# 2643  [Warner Bros., Roadshow Entertainment, (Austra...
# 2885  [Universal Pictures, (North America), Metro-Go...
# 1842                              Warner Bros. Pictures
# 186                                     New Line Cinema
#
#                                               Editor(s)      Composer(s)  \
# 364   [Michael Mulconery, David Rawlins, Anthony Red...      John Morris
# 2643                                        Jay Cassidy    Graeme Revell
# 2885                                     Peter Teschner    John Frizzell
# 1842                                         Dan Molina  Steve Goldstein
# 186                                          Larry Rock   Cliff Martinez
#
#                                             Producer(s)  \
# 364                                          Mel Brooks
# 2643                  [Jeffrey Silver, Joel Schumacher]
# 2885  [Marc Platt, Tracey E. Edmonds, Chuck Grimes, ...
# 1842  [Bill Bloom, Timothy Campbell, Paul Gertz, Dav...
# 186   [Syd Cappe, Sara Risher, Sandy Stern, Nicolas ...
#
#                                   Production company(s)  \
# 364                                         Brooksfilms
# 2643                          Village Roadshow Pictures
# 2885  [Universal Pictures, Metro-Goldwyn-Mayer, Marc...
# 1842  [Turner Feature Animation, Warner Bros. Animat...
# 186                                                 NaN
#
#                                               Writer(s)    imdb_id
# 364   [Mel Brooks, Ron Clark, Rudy De Luca, Steve Ha...  tt0102303
# 2643                  [Gregory Poirier, Theresa Rebeck]  tt0176783
# 2885                     [Harry Elfont, Deborah Kaplan]  tt0236348
# 1842                               Sandy Russell Gartin  tt0118829
# 186                                         Allan Moyle  tt0100436
#
# [5 rows x 21 columns]
